# %% [markdown]
# # AWS MWAA

# %% [markdown]
# ## What does AWS MWAA stand for?
#
# - A. Amazon Web Services Managed Web Application Analytics service
# - B. Amazon Web Services Managed Workflow Automation service
# - C. Amazon Web Services Managed Workflows for Apache Airflow service ***
# - D. Amazon Web Services Managed Website Acceleration service

# %% [markdown]
# ## Which of the following is a feature of Amazon Web Services Managed Workflows for Apache Airflow (MWAA)?
#
# - A. Serverless compute and storage
# - B. Customizable security policies
# - C. Managed Apache Airflow software updates
# - D. All of the above ***

# %% [markdown]
# ## What is the role of the scheduler, executor, and workers in the AWS Managed Workflows for Apache Airflow (MWAA) environment?
#
# - A. The scheduler creates and manages DAGs, the executor runs the DAGs, and the workers perform the tasks in the DAGs. ***
# - B. The scheduler performs the tasks in the DAGs, the executor manages the workers, and the workers create and manage DAGs.
# - C. The scheduler creates and manages workflows, the executor runs the workflows, and the workers perform the tasks in the workflows.
# - D. The scheduler creates and manages tasks, the executor runs the tasks, and the workers manage the DAGs.

# %% [markdown]
# ## What is the purpose of the metadata database used by Apache Airflow in Amazon Web Services Managed Workflows for Apache Airflow (MWAA)?
#
# - A. To store the variables and connections configurations
# - B. To store the user information, role and policies
# - C. To store the DAG-related metadata
# - D. All the above ***

# %% [markdown]
# ## What is the purpose of the MWAA webserver in Amazon Web Services Managed Workflows for Apache Airflow (MWAA)?
#
# - A. To manage and monitor the metadata database
# - B. To execute the DAGs and tasks in the workflows
# - C. To provide a web-based interface for managing and monitoring the workflows
# - D. To store the output and logs generated by the DAG runs and task instances ***

# %% [markdown]
# ## What are the steps to create an Apache Airflow environment using the Amazon Web Services Managed Workflows for Apache Airflow (MWAA) Management Console?
#
# - A. Choose "Create environment" from the console, select the MWAA environment type, choose the VPC, security settings, and storage options, and then review and create the environment.***
#
# - B. Choose "Create environment" from the console, select the EC2 instance type, choose the AMI, configure the networking and security, and then launch the environment.
#
# - C. Choose "Create environment" from the console, select the Lambda function type, configure the function code and settings, and then deploy the environment.
#
# - D. Choose "Create environment" from the console, select the ECS container type, choose the task definition, configure the cluster and networking, and then start the environment.

# %% [markdown]
# ## What are the required features of an Amazon S3 bucket used for an Amazon Web Services Managed Workflows for Apache Airflow (MWAA) environment?
#
# - A. The bucket must have versioning enabled and an IAM policy granting MWAA access to the bucket ***
# - B. The bucket must have public access enabled and a lifecycle policy to delete old files
# - C. The bucket must have server-side encryption enabled and a bucket policy allowing public read access
# - D. The bucket must have object locking enabled and a bucket policy allowing write access to the MWAA service
