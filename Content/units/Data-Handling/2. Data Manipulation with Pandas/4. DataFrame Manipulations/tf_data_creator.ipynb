# %%
import pandas as pd
flights = pd.read_csv('flights_sample.csv')

# %%
cancellations = flights[['CANCELLED']].head(50)
cancellations.to_csv('cancellations.csv', index=False)

# %%
cancellations.head(30)
# Out:
#    CANCELLED
# 0          F
# 1      False
# 2          F
# 3      False
# 4          0
# 5          F
# 6          T
# 7          F
# 8          F
# 9          F
# 10     False
# 11         0
# 12     False
# 13     False
# 14     False
# 15     False
# 16         0
# 17         0
# 18         1
# 19     False
# 20         0
# 21      True
# 22         F
# 23     False
# 24     False
# 25     False
# 26     False
# 27         0
# 28         0
# 29     False
